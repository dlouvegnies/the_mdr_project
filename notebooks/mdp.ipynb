# %%
import mysql.connector

config = {
    'user': 'db123270',
    'password': '123edFrTDE',
    'host': 'db20201-sumertwist.sql-pro.online.net',
    'database': 'db20201_sumertwist',
    'raise_on_warnings': True
}

try:
    # Connexion à la base de données
    connexion = mysql.connector.connect(**config)

    if connexion.is_connected():
        print('Connexion réussie à la base de données')

        # Exécution de requêtes
        cursor = connexion.cursor()

        # Exemple de requête
        cursor.execute("SELECT VERSION()")
        version = cursor.fetchone()
        print("Version du serveur MySQL :", version)

        # Fermeture du curseur et de la connexion
        cursor.close()
        connexion.close()
        print('Connexion à la base de données fermée')

except mysql.connector.Error as err:
    print("Erreur de connexion à la base de données :", err)
# Out:
# Connexion réussie à la base de données
# Version du serveur MySQL : ('8.0.36-0ubuntu0.22.04.1',)
# Connexion à la base de données fermée

# %%
import mysql.connector

# Paramètres de connexion à la base de données
config = {
    'user': 'db123270',
    'password': '123edFrTDE',
    'host': 'db20201-sumertwist.sql-pro.online.net',
    'database': 'db20201_sumertwist',
    'raise_on_warnings': True
}

try:
    # Connexion à la base de données
    connexion = mysql.connector.connect(**config)

    if connexion.is_connected():
        print('Connexion réussie à la base de données')

        # Exécution de la requête pour récupérer le contenu de la table "review"
        cursor = connexion.cursor()
        cursor.execute("SELECT * FROM review_dataset")

        # Récupération des résultats
        rows = cursor.fetchall()

        # Affichage des résultats
        for row in rows:
            print(row)

        # Fermeture du curseur et de la connexion
        cursor.close()
        connexion.close()
        print('Connexion à la base de données fermée')

except mysql.connector.Error as err:
    print("Erreur de connexion à la base de données :", err)
# Out:
# Connexion réussie à la base de données
# (1, 1, 123, 1, 0, datetime.datetime(2024, 3, 21, 9, 47, 1))
# Connexion à la base de données fermée

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# Informations de connexion à la base de données MySQL
host = 'db20201-sumertwist.sql-pro.online.net'
database = 'db20201_sumertwist'
user = 'db123270'
password = '123edFrTDE'


# Création du DataFrame à partir de vos données ou d'un fichier CSV par exemple
data = {
    'column1': [1, 2, 3],
    'column2': ['A', 'B', 'C']
}
df = pd.DataFrame(data)

df = pd.read_csv("../raw_data/only_today_export_2024-03-21.csv")

try:
    # Connexion à la base de données MySQL
    engine = create_engine(f'mysql+mysqlconnector://{user}:{password}@{host}/{database}')

    # Insertion du DataFrame dans la table MySQL
    df.to_sql(name='nom_de_votre_table', con=engine, if_exists='replace', index=False)

    print("Données insérées dans la table MySQL avec succès.")

except mysql.connector.Error as err:
    print("Erreur de connexion à la base de données MySQL :", err)

# %%
df = pd.read_csv("../raw_data/only_today_export_2024-03-21.csv")
df.dtypes
# Out:
# source         object
# theme          object
# soustheme      object
# title          object
# description    object
# link           object
# published      object
# image          object
# added_date     object
# dtype: object

# %%
import pandas as pd
import mysql.connector

# Informations de connexion à la base de données MySQL
host = 'db20201-sumertwist.sql-pro.online.net'
database = 'db20201_sumertwist'
user = 'db123270'
password = '123edFrTDE'

# Création du DataFrame à partir de vos données ou d'un fichier CSV par exemple
data = {
    'column1': [1, 2, 3],
    'column2': ['A', 'B', 'C']
}
df = pd.DataFrame(data)

df = pd.read_csv("../raw_data/only_today_export_2024-03-21.csv")

try:
    # Connexion à la base de données MySQL
    connexion = mysql.connector.connect(host=host, database=database, user=user, password=password)

    if connexion.is_connected():
        print('Connexion réussie à la base de données')

        # Création du curseur
        cursor = connexion.cursor()

        compteur=0
        # Insertion des données ligne par ligne
        for index, row in df.iterrows():
            if compteur<1 :
                sql = "INSERT INTO nom_de_votre_table (column1, column2,title) VALUES (%s, %s,%s)"
                cursor.execute(sql, (row['source'], row['theme'],row['title']))
                print(f"Donnée insérée :{compteur}- {row['title']}, {row['theme']}")
                compteur = compteur + 1
                connexion.commit()

        # Validation des changements et fermeture du curseur
        #connexion.commit()
        cursor.close()
        connexion.close()
        print('Données insérées avec succès. Connexion à la base de données fermée')

except mysql.connector.Error as err:
    print("Erreur de connexion à la base de données MySQL :", err)
# Out:
# Connexion réussie à la base de données
# Donnée insérée :0- Analyse d’un roman (68e épisode), culture
# Données insérées avec succès. Connexion à la base de données fermée

# %% [markdown]
# ## Test d'une query sur la category

# %%
import pandas as pd
import mysql.connector

# Informations de connexion à la base de données MySQL
host = 'db20201-sumertwist.sql-pro.online.net'
database = 'db20201_sumertwist'
user = 'db123270'
password = '123edFrTDE'


# Création de la chaîne de connexion à la base de données
connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"

try:
    # Création du moteur SQLAlchemy
    engine = create_engine(connection_string)

    # Requête SQL SELECT
    query = "SELECT * FROM category_dataset"

    # Exécution de la requête et chargement des résultats dans un DataFrame
    cat_df = pd.read_sql_query(query, engine)

except Exception as e:
    print("Erreur lors de l'exécution de la requête :", e)

print("Résultats de la requête :")
cat_df
# Out:
# Résultats de la requête :
#     category_id       cat_name
# 0             1        culture
# 1             2        musique
# 2             3    technologie
# 3             4      politique
# 4             5          sport
# 5             6       economie
# 6             7  environnement
# 7             8        general
# 8             9         emploi
# 9            10           cite
# 10           11     management
# 11           12         presse
# 12           13       nustrale
# 13           14       tourisme

# %%
data_df = pd.read_csv('../raw_data/only_today_export_2024-03-21_cleaned.csv')

# Dataframe which is associate withe the news table
result = data_df.merge(cat_df, left_on='theme', right_on='cat_name')
news_df = result[['category_id', 'title', 'description', 'link','image', 'added_date', 'source', 'soustheme']]
news_df = news_df.rename(columns={'soustheme': 'sub_cat'})
news_df.head(3)
# Out:
#    category_id                                              title  \
# 0            1                   Analyse d’un roman (68e épisode)
# 1            1  Un remake annoncé pour ce film culte des année...
# 2            1  Equilibrium : pourquoi ça aurait dû être un gr...
#
#                                          description  \
# 0  Dans ce nouvel épisode de la série « L’Alchimi...
# 1  Les producteurs du Discours d'un roi ont annon...
# 2  Film de science-fiction sorti au cinéma en 200...
#
#                                                 link image  \
# 0  https://www.aproposdecriture.com/analyse-dun-r...   NaN
# 1  https://www.ecranlarge.com/films/news/1505931-...   NaN
# 2  https://www.ecranlarge.com/films/news/1505944-...   NaN
#
#             added_date               source      sub_cat
# 0  2024-03-21 09:00:00  À propos d'écriture  litterature
# 1  2024-03-21 09:00:00          Écran large       cinema
# 2  2024-03-21 09:00:00          Écran large       cinema

# %% [markdown]
# ## IMPORT DES NEWS DANS MYSQL

# %%
import pandas as pd
import mysql.connector

# Informations de connexion à la base de données MySQL
host = 'db20201-sumertwist.sql-pro.online.net'
database = 'db20201_sumertwist'
user = 'db123270'
password = '123edFrTDE'

#df = pd.read_csv("../raw_data/only_today_export_2024-03-21.csv")
news_df=news_df.fillna("")

try:
    # Connexion à la base de données MySQL
    connexion = mysql.connector.connect(host=host, database=database, user=user, password=password)

    if connexion.is_connected():
        print('Connexion réussie à la base de données')

        # Création du curseur
        cursor = connexion.cursor()

        compteur=0
        # Insertion des données ligne par ligne
        for index, row in news_df.iterrows():
            if compteur<1000000 :
                sql = "INSERT INTO news_dataset (category_id,title,description,link,image,added_date,source,sub_cat) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
                cursor.execute(sql, (row['category_id'], row['title'],row['description'],row['link'],row['image'],row['added_date'],row['source'],row['sub_cat']))
                print(f"Donnée insérée :{compteur}- {row['title']}, {row['category_id']}")
                compteur = compteur + 1
                #connexion.commit()

        # Validation des changements et fermeture du curseur
        connexion.commit()
        cursor.close()
        connexion.close()
        print('Données insérées avec succès. Connexion à la base de données fermée')

except mysql.connector.Error as err:
    print("Erreur de connexion à la base de données MySQL :", err)

# %%
from google.cloud.sql.connector import Connector
import sqlalchemy
import pymysql

# initialize Connector object
connector = Connector()

# function to return the database connection
def getconn() -> pymysql.connections.Connection:
    conn: pymysql.connections.Connection = connector.connect(
        "the-mdr-project:europe-west1:mdr-project",
        "pymysql",
        user="user_db",
        password="q0O3m^+2cGkZ%O(r",
        db="mdr_v1"
    )
    return conn

# create connection pool
pool = sqlalchemy.create_engine(
    "mysql+pymysql://",
    creator=getconn,
)
pool.connect()
# Out:
# ['the-mdr-project:europe-west1:mdr-project']: An error occurred while performing refresh. Scheduling another refresh attempt immediately
# Traceback (most recent call last):
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 312, in _refresh_task
#     refresh_data = await refresh_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 247, in _perform_refresh
#     metadata = await metadata_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/client.py", line 124, in _get_metadata
#     resp = await self._client.get(url, headers=headers, raise_for_status=True)
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client.py", line 693, in _request
#     resp.raise_for_status()
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 1060, in raise_for_status
#     raise ClientResponseError(
# aiohttp.client_exceptions.ClientResponseError: 403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')
# ['the-mdr-project:europe-west1:mdr-project']: An error occurred while performing refresh. Scheduling another refresh attempt immediately
# Traceback (most recent call last):
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 312, in _refresh_task
#     refresh_data = await refresh_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 247, in _perform_refresh
#     metadata = await metadata_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/client.py", line 124, in _get_metadata
#     resp = await self._client.get(url, headers=headers, raise_for_status=True)
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client.py", line 693, in _request
#     resp.raise_for_status()
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 1060, in raise_for_status
#     raise ClientResponseError(
# aiohttp.client_exceptions.ClientResponseError: 403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')
# Task exception was never retrieved
# future: <Task finished name='Task-22' coro=<Instance._schedule_refresh.<locals>._refresh_task() done, defined at /Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py:301> exception=ClientResponseError(RequestInfo(url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings'), method='GET', headers=<CIMultiDictProxy('Host': 'sqladmin.googleapis.com', 'x-goog-api-client': 'cloud-sql-python-connector/1.8.0+pymysql', 'User-Agent': 'cloud-sql-python-connector/1.8.0+pymysql', 'Content-Type': 'application/json', 'Authorization': 'Bearer ya29.c.c0AY_VpZgm8hf_DEf8v3tLWk1UNkYdJrUgcKK7wJAvbhaqBg_UUwFlGJrNrG13pLI40WSxbqfpS6tE91mrR7_XHGk7HD7HHD6a2t9AZSvNiNPofhQlV9RuI_J1MRRPVJVjTu-REztgLQPs6vkibR-AKl0TFw0aq12NUDgwCu-r0ewVP2UwmxUCj74WwXa9ioniWWDSjVFj6atmWrVJegak5d28WdnEiF6fG1Gd2l8CUDDijX2l2AuXC9I52oUjWal3xs9nQ75giy_2AW7DIMfrxY2bzgacxGGibjz-lBelZYvVxY64RLspJyt1uhMj7vKbWYxoYA2YeqCVeflF60PXNpX69TqRaofkPr8BGVq_0I6bj_rSPSvwQCAH384KeInlIthzhw0rFWfUykJ1tnwyzX9dSs7byiaxBd_mrmz6-Sybw3_UZzwYvpIBqsb_vf7I25kkXfBcttjXgkk2U55YkqxuUiMihu9lgy_QRoqumZlWZ0W2paanmOlgzeyMQ0t2BZZgdgh9j4vfabwdyucMepspdoUYswUop40WtVzYtcdpJ0tuisQOoV-7SvegvhgBk0enshrexwwJgb-dhS1tYUepg96MRw_OJ_RaMSlf-myFBfvckxZbjUocUWw7xnW300Bs8fyev-sx5ka_ir3Sm5SBVmqFSWn1gmFYsWY8whnf_5tRjdQ2ksdOqz8Wvwefej4WzeRiqo0sgt7l3t8oV9q14YdJ6uIcUQ_SJuIZu4WVYaQRIfoRh7xZ8bnFamYUo-MiyIbh4k79gufBekts7mulvdIjrMfa5cxxk19w-ZRJsac0SuflZ60pkpuUoWfYY7u9oMB_iUU7gMhpnlhqW8hvrd-fgV6Wf4tRloy3Frh-4usyf38vqqRbd4Rl4ja7nfokw8Xm24gQbRfu1iUw1IJnsrR6vw-IB-ZbRqMReVImUJM21mSXes0YXYZh0kJz6I4JUsMhlOveYiW-9ZfOhsgJ8rMcaaega9ex-MdtQbawFaFlJIjshpe', 'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate')>, real_url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')), (), status=403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", headers=<CIMultiDictProxy('Vary': 'Origin', 'Vary': 'X-Origin', 'Vary': 'Referer', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Encoding': 'gzip', 'Date': 'Thu, 21 Mar 2024 12:27:22 GMT', 'Server': 'ESF', 'Cache-Control': 'private', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked')>)>
# Traceback (most recent call last):
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 312, in _refresh_task
#     refresh_data = await refresh_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 247, in _perform_refresh
#     metadata = await metadata_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/client.py", line 124, in _get_metadata
#     resp = await self._client.get(url, headers=headers, raise_for_status=True)
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client.py", line 693, in _request
#     resp.raise_for_status()
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 1060, in raise_for_status
#     raise ClientResponseError(
# aiohttp.client_exceptions.ClientResponseError: 403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# Cell In[5], line 24
#      19 # create connection pool
#      20 pool = sqlalchemy.create_engine(
#      21     "mysql+pymysql://",
#      22     creator=getconn,
#      23 )
# ---> 24 pool.connect()
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3279, in Engine.connect(self)
#    3256 def connect(self) -> Connection:
#    3257     """Return a new :class:`_engine.Connection` object.
#    3258
#    3259     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3276
#    3277     """
# -> 3279     return self._connection_cls(self)
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3303, in Engine.raw_connection(self)
#    3281 def raw_connection(self) -> PoolProxiedConnection:
#    3282     """Return a "raw" DBAPI connection from the connection pool.
#    3283
#    3284     The returned object is a proxied version of the DBAPI
#    (...)
#    3301
#    3302     """
# -> 3303     return self.pool.connect()
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/sqlalchemy/pool/base.py:362, in Pool._should_wrap_creator.<locals>.<lambda>(rec)
#     358 # all other cases, just wrap and assume legacy "creator" callable
#     359 # thing
#     360 else:
#     361     creator_fn = cast(_CreatorFnType, creator)
# --> 362     return lambda rec: creator_fn()
#
# Cell In[5], line 10, in getconn()
#       9 def getconn() -> pymysql.connections.Connection:
# ---> 10     conn: pymysql.connections.Connection = connector.connect(
#      11         "the-mdr-project:europe-west1:mdr-project",
#      12         "pymysql",
#      13         user="user_db",
#      14         password="q0O3m^+2cGkZ%O(r",
#      15         db="mdr_v1"
#      16     )
#      17     return conn
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/connector.py:182, in Connector.connect(self, instance_connection_string, driver, **kwargs)
#     178 # if event loop is not in current thread, proceed with connection
#     179 connect_task = asyncio.run_coroutine_threadsafe(
#     180     self.connect_async(instance_connection_string, driver, **kwargs), self._loop
#     181 )
# --> 182 return connect_task.result()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/connector.py:271, in Connector.connect_async(self, instance_connection_string, driver, **kwargs)
#     269 # attempt to make connection to Cloud SQL instance
#     270 try:
# --> 271     instance_data, ip_address = await instance.connect_info(ip_type)
#     272     # resolve DNS name into IP address for PSC
#     273     if ip_type.value == "PSC":
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py:369, in Instance.connect_info(self, ip_type)
#     363 logger.debug(
#     364     f"['{self._instance_connection_string}']: Entered connect_info method"
#     365 )
#     367 instance_data: ConnectionInfo
# --> 369 instance_data = await self._current
#     370 ip_address: str = instance_data.get_preferred_ip(ip_type)
#     371 return instance_data, ip_address
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py:312, in Instance._schedule_refresh.<locals>._refresh_task(self, delay)
#     310         await asyncio.sleep(delay)
#     311     refresh_task = asyncio.create_task(self._perform_refresh())
# --> 312     refresh_data = await refresh_task
#     313 except asyncio.CancelledError:
#     314     logger.debug(
#     315         f"['{self._instance_connection_string}']: Schedule refresh task cancelled."
#     316     )
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py:247, in Instance._perform_refresh(self)
#     238 ephemeral_task = asyncio.create_task(
#     239     self._client._get_ephemeral(
#     240         self._project,
#    (...)
#     244     )
#     245 )
#     246 try:
# --> 247     metadata = await metadata_task
#     248     # check if automatic IAM database authn is supported for database engine
#     249     if self._enable_iam_auth and not metadata[
#     250         "database_version"
#     251     ].startswith(("POSTGRES", "MYSQL")):
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/client.py:124, in CloudSQLClient._get_metadata(self, project, region, instance)
#     120 url = f"{self._sqladmin_api_endpoint}/sql/{API_VERSION}/projects/{project}/instances/{instance}/connectSettings"
#     122 logger.debug(f"['{instance}']: Requesting metadata")
# --> 124 resp = await self._client.get(url, headers=headers, raise_for_status=True)
#     125 ret_dict = await resp.json()
#     127 if ret_dict["region"] != region:
#
# File ~/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client.
users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py:301> exception=ClientResponseError(RequestInfo(url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings'), method='GET', headers=<CIMultiDictProxy('Host': 'sqladmin.googleapis.com', 'x-goog-api-client': 'cloud-sql-python-connector/1.8.0+pymysql', 'User-Agent': 'cloud-sql-python-connector/1.8.0+pymysql', 'Content-Type': 'application/json', 'Authorization': 'Bearer ya29.c.c0AY_VpZg9c4gFwhbmvXHsVM3rrDYqieTgbRUwy6qjeQPeNVWpfOMcT9_GMxPYgR_Lnk87tqlEUWwN3KRoA2-JGjNabyH6r2XDjw0jipu1dm7bb-yuUEFNhUINwmIuZ7B6KOQF1yi3i85tejBIZ7A_QZqHvhm2aKq6peIRm_78QIYM-B13eIZEnv1iEIgMldOpGET1r0T2Ht0cWqtwER7Qbf0drGZXGzfycjU5FOys83b9IIEevBooRuFWKQyEH5zXkaQ4GUx9y5LUvux5dT7QRnMGmYbs6b4IMQqibmWhe7aQ2JwVcz7heNgCyilcYP9cWQmRC5l1aM9Iw_f7r1xhkZWJzxp7pdjZ453XbVEwKF03GLmKUg2gpQH383PBdlfdS9IrZakh17sp7vk5-IiqV1fdJhXOIeBZ8yRezMfw55S9jwkd668ShaUV5upR3F5sucq7w25p1JvtZXYY1pf-Ir-lxZSwzi9kIax-yhlSuiInxjiZVnhI2okVIgabyq1SYiYddi-mOvoZIFRudJoRVI566e9ri2vQxM2yc3txl0Bp5zOMS8IZ8W-vcYIWZ8fIfco90R8OM3eZJwysFUVFFiR9vz4Ow5JoRev8gi9hRfxec5xobuSVXIhXF9J8sJdQeye3UfcdwJZu-6uscbryknXiznhcl3bBMikyzBZj9egxno9OQYYmtYFSkbq5Valn5eRRgxfjm75MgIfVF5pMQcc283-XRh2BWpYO48rl3fcn9wedpInfzOY5ceYJof-FJ3hady92o7vnh_YXul3Iqm02XZvs1JbmeJMVJJu1unX2Oj02dYXQcgl2z36pJbR8UkzWe_1_J1hiwwuh0xwgeJl10FuduJ5SrdaxtQ4JWBmgW8R9IUyrm_yZBgwWQ0pQ0l_oJqz5MW9eSnbYv-8xhQlygIp5w6-jzattUXV4r22cowR2cvXrV8cRy_V_4iiZfS0c3xUB_oe_-aSpSI8uVQdZf2_UoM5pef8ShxQOvRXXOyrh-OzyVZ9', 'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate')>, real_url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')), (), status=403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", headers=<CIMultiDictProxy('Vary': 'Origin', 'Vary': 'X-Origin', 'Vary': 'Referer', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Encoding': 'gzip', 'Date': 'Thu, 21 Mar 2024 13:35:51 GMT', 'Server': 'ESF', 'Cache-Control': 'private', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked')>)>
# Traceback (most recent call last):
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 312, in _refresh_task
#     refresh_data = await refresh_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/instance.py", line 247, in _perform_refresh
#     metadata = await metadata_task
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/google/cloud/sql/connector/client.py", line 124, in _get_metadata
#     resp = await self._client.get(url, headers=headers, raise_for_status=True)
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client.py", line 693, in _request
#     resp.raise_for_status()
#   File "/Users/denislouvegnies/.pyenv/versions/3.10.6/envs/the_mdr_project/lib/python3.10/site-packages/aiohttp/client_reqrep.py", line 1060, in raise_for_status
#     raise ClientResponseError(
# aiohttp.client_exceptions.ClientResponseError: 403, message="Forbidden: Authenticated IAM principal does not seeem authorized to make API request. Verify 'Cloud SQL Admin API' is enabled within your GCP project and 'Cloud SQL Client' role has been granted to IAM principal.", url=URL('https://sqladmin.googleapis.com/sql/v1beta4/projects/the-mdr-project/instances/mdr-project/connectSettings')
